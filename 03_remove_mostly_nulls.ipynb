# %% [markdown]
# # Remove Mostly Nulls
#
# In this notebook we do two things:
#
# 1. We replace the `loan_status` column with a 0, 1.
# 2. We remove the columns that have mostly null values.

# %% [markdown]
# ### Importing Packages

# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 200

# %% [markdown]
# ### Reading-In Data

# %%
df_binary = pd.read_csv("data_processed/01_binary.csv", low_memory=False)
df_binary.head(3).T
# Out:
#                                                                                             0
# id                                                                                   39460023  \
# member_id                                                                                 NaN
# loan_amnt                                                                              5625.0
# funded_amnt                                                                            5625.0
# funded_amnt_inv                                                                        5625.0
# term                                                                                36 months
# int_rate                                                                                12.39
# installment                                                                            187.89
# grade                                                                                       C
# sub_grade                                                                                  C1
# emp_title                                                                             Teacher
# emp_length                                                                            3 years
# home_ownership                                                                           RENT
# annual_inc                                                                            44000.0
# verification_status                                                              Not Verified
# issue_d                                                                              Jan-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                    debt_consolidation
# title                                                                      Debt consolidation
# zip_code                                                                                287xx
# addr_state                                                                                 NC
# dti                                                                                     23.65
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Jul-1987
# fico_range_low                                                                          730.0
# fico_range_high                                                                         734.0
# inq_last_6mths                                                                            1.0
# mths_since_last_delinq                                                                   28.0
# mths_since_last_record                                                                   24.0
# open_acc                                                                                 13.0
# pub_rec                                                                                   1.0
# revol_bal                                                                             29458.0
# revol_util                                                                               44.9
# total_acc                                                                                34.0
# initial_list_status                                                                         w
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                           6299.17
# total_pymnt_inv                                                                       6299.17
# total_rec_prncp                                                                        5625.0
# total_rec_int                                                                          674.17
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Feb-2016
# last_pymnt_amnt                                                                       4048.36
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2019
# last_fico_range_high                                                                    604.0
# last_fico_range_low                                                                     600.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                             80.0
# tot_cur_bal                                                                          239578.0
# open_acc_6m                                                                               NaN
# open_act_il                                                                               NaN
# open_il_12m                                                                               NaN
# open_il_24m                                                                               NaN
# mths_since_rcnt_il                                                                        NaN
# total_bal_il                                                                              NaN
# il_util                                                                                   NaN
# open_rv_12m                                                                               NaN
# open_rv_24m                                                                               NaN
# max_bal_bc                                                                                NaN
# all_util                                                                                  NaN
# total_rev_hi_lim                                                                      65600.0
# inq_fi                                                                                    NaN
# total_cu_tl                                                                               NaN
# inq_last_12m                                                                              NaN
# acc_open_past_24mths                                                                      2.0
# avg_cur_bal                                                                           18429.0
# bc_open_to_buy                                                                        13497.0
# bc_util                                                                                  64.9
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      176.0
# mo_sin_old_rev_tl_op                                                                    330.0
# mo_sin_rcnt_rev_tl_op                                                                     2.0
# mo_sin_rcnt_tl                                                                            2.0
# mort_acc                                                                                  4.0
# mths_since_recent_bc                                                                     32.0
# mths_since_recent_bc_dlq                                                                  NaN
# mths_since_recent_inq                                                                     2.0
# mths_since_recent_revol_delinq                                                            NaN
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            5.0
# num_actv_rev_tl                                                                           8.0
# num_bc_sats                                                                               5.0
# num_bc_tl                                                                                11.0
# num_il_tl                                                                                 8.0
# num_op_rev_tl                                                                            11.0
# num_rev_accts                                                                            22.0
# num_rev_tl_bal_gt_0                                                                       8.0
# num_sats                                                                                 13.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        1.0
# pct_tl_nvr_dlq                                                                           97.1
# percent_bc_gt_75                                                                         80.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 1.0
# tot_hi_cred_lim                                                                      293006.0
# total_bal_ex_mort                                                                     48862.0
# total_bc_limit                                                                        38400.0
# total_il_high_credit_limit                                                            20093.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             1
# id                                                                                   38202144  \
# member_id                                                                                 NaN
# loan_amnt                                                                             25000.0
# funded_amnt                                                                           25000.0
# funded_amnt_inv                                                                       25000.0
# term                                                                                36 months
# int_rate                                                                                 6.49
# installment                                                                            766.12
# grade                                                                                       A
# sub_grade                                                                                  A2
# emp_title                                                    Business Development Coordinator
# emp_length                                                                            4 years
# home_ownership                                                                           RENT
# annual_inc                                                                            91000.0
# verification_status                                                           Source Verified
# issue_d                                                                              Jan-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                           credit_card
# title                                                                 Credit card refinancing
# zip_code                                                                                606xx
# addr_state                                                                                 IL
# dti                                                                                     12.22
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Sep-2000
# fico_range_low                                                                          735.0
# fico_range_high                                                                         739.0
# inq_last_6mths                                                                            1.0
# mths_since_last_delinq                                                                   44.0
# mths_since_last_record                                                                    NaN
# open_acc                                                                                  8.0
# pub_rec                                                                                   0.0
# revol_bal                                                                             21567.0
# revol_util                                                                               33.0
# total_acc                                                                                33.0
# initial_list_status                                                                         f
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                          27139.18
# total_pymnt_inv                                                                      27139.18
# total_rec_prncp                                                                       25000.0
# total_rec_int                                                                         2139.18
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Oct-2016
# last_pymnt_amnt                                                                      11834.81
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Oct-2016
# last_fico_range_high                                                                    774.0
# last_fico_range_low                                                                     770.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                              0.0
# tot_cur_bal                                                                           38781.0
# open_acc_6m                                                                               NaN
# open_act_il                                                                               NaN
# open_il_12m                                                                               NaN
# open_il_24m                                                                               NaN
# mths_since_rcnt_il                                                                        NaN
# total_bal_il                                                                              NaN
# il_util                                                                                   NaN
# open_rv_12m                                                                               NaN
# open_rv_24m                                                                               NaN
# max_bal_bc                                                                                NaN
# all_util                                                                                  NaN
# total_rev_hi_lim                                                                      65400.0
# inq_fi                                                                                    NaN
# total_cu_tl                                                                               NaN
# inq_last_12m                                                                              NaN
# acc_open_past_24mths                                                                      4.0
# avg_cur_bal                                                                            4848.0
# bc_open_to_buy                                                                        39833.0
# bc_util                                                                                  35.1
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      149.0
# mo_sin_old_rev_tl_op                                                                    171.0
# mo_sin_rcnt_rev_tl_op                                                                    10.0
# mo_sin_rcnt_tl                                                                           10.0
# mort_acc                                                                                  1.0
# mths_since_recent_bc                                                                     11.0
# mths_since_recent_bc_dlq                                                                 67.0
# mths_since_recent_inq                                                                     2.0
# mths_since_recent_revol_delinq                                                           67.0
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            3.0
# num_actv_rev_tl                                                                           3.0
# num_bc_sats                                                                               5.0
# num_bc_tl                                                                                14.0
# num_il_tl                                                                                 9.0
# num_op_rev_tl                                                                             7.0
# num_rev_accts                                                                            21.0
# num_rev_tl_bal_gt_0                                                                       3.0
# num_sats                                                                                  8.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        2.0
# pct_tl_nvr_dlq                                                                           93.7
# percent_bc_gt_75                                                                          0.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                       92905.0
# total_bal_ex_mort                                                                     38781.0
# total_bc_limit                                                                        61400.0
# total_il_high_credit_limit                                                            27505.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             2
# id                                                                                   17343169
# member_id                                                                                 NaN
# loan_amnt                                                                             16000.0
# funded_amnt                                                                           16000.0
# funded_amnt_inv                                                                       15950.0
# term                                                                                60 months
# int_rate                                                                                19.52
# installment                                                                            419.65
# grade                                                                                       E
# sub_grade                                                                                  E2
# emp_title                                                                          supervisor
# emp_length                                                                          10+ years
# home_ownership                                                                            OWN
# annual_inc                                                                            55000.0
# verification_status                                                                  Verified
# issue_d                                                                              May-2014
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                    debt_consolidation
# title                                                                      Debt consolidation
# zip_code                                                                                726xx
# addr_state                                                                                 AR
# dti                                                                                     23.57
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Jan-1996
# fico_range_low                                                                          670.0
# fico_range_high                                                                         674.0
# inq_last_6mths                                                                            1.0
# mths_since_last_delinq                                                                   42.0
# mths_since_last_record                                                                    NaN
# open_acc                                                                                  7.0
# pub_rec                                                                                   0.0
# revol_bal                                                                             23248.0
# revol_util                                                                               96.9
# total_acc                                                                                23.0
# initial_list_status                                                                         f
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                      24513.564059
# total_pymnt_inv                                                                      24436.96
# total_rec_prncp                                                                       16000.0
# total_rec_int                                                                         8513.56
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Mar-2018
# last_pymnt_amnt                                                                       6048.96
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2018
# last_fico_range_high                                                                    664.0
# last_fico_range_low                                                                     660.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                             64.0
# tot_cur_bal                                                                           35446.0
# open_acc_6m                                                                               NaN
# open_act_il                                                                               NaN
# open_il_12m                                                                               NaN
# open_il_24m                                                                               NaN
# mths_since_rcnt_il                                                                        NaN
# total_bal_il                                                                              NaN
# il_util                                                                                   NaN
# open_rv_12m                                                                               NaN
# open_rv_24m                                                                               NaN
# max_bal_bc                                                                                NaN
# all_util                                                                                  NaN
# total_rev_hi_lim                                                                      24000.0
# inq_fi                                                                                    NaN
# total_cu_tl                                                                               NaN
# inq_last_12m                                                                              NaN
# acc_open_past_24mths                                                                      4.0
# avg_cur_bal                                                                            5064.0
# bc_open_to_buy                                                                          237.0
# bc_util                                                                                  98.4
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      143.0
# mo_sin_old_rev_tl_op                                                                    220.0
# mo_sin_rcnt_rev_tl_op                                                                     6.0
# mo_sin_rcnt_tl                                                                            6.0
# mort_acc                                                                                  0.0
# mths_since_recent_bc                                                                      6.0
# mths_since_recent_bc_dlq                                                                  NaN
# mths_since_recent_inq                                                                     6.0
# mths_since_recent_revol_delinq                                                           42.0
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            2.0
# num_actv_rev_tl                                                                           5.0
# num_bc_sats                                                                               2.0
# num_bc_tl                                                                                 2.0
# num_il_tl                                                                                15.0
# num_op_rev_tl                                                                             5.0
# num_rev_accts                                                                             8.0
# num_rev_tl_bal_gt_0                                                                       5.0
# num_sats                                                                                  7.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        2.0
# pct_tl_nvr_dlq                                                                           95.7
# percent_bc_gt_75                                                                        100.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                       43167.0
# total_bal_ex_mort                                                                     35446.0
# total_bc_limit                                                                        14500.0
# total_il_high_credit_limit                                                            19167.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN

# %% [markdown]
# ### Create 0,1 Label called `charged_off` and Remove `loan_status`

# %% [markdown]
# First, lets check the output of the `pd.get_dummies()` method when applied to the `loan_status` column.

# %%
pd.get_dummies(df_binary[["loan_status"]])
# Out:
#         loan_status_Charged Off  loan_status_Fully Paid
# 0                         False                    True
# 1                         False                    True
# 2                         False                    True
# 3                         False                    True
# 4                         False                    True
# ...                         ...                     ...
# 594765                    False                    True
# 594766                    False                    True
# 594767                    False                    True
# 594768                    False                    True
# 594769                     True                   False
#
# [594770 rows x 2 columns]

# %%
df_binary["charged_off"] = pd.get_dummies(df_binary[["loan_status"]])["loan_status_Charged Off"]

# %%
df_binary.drop(columns=["loan_status"], inplace=True)

# %% [markdown]
# ### Identifying Mostly `NaN` Columns

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# The following code identifies the `NaN` in each column.

# %%
df_binary.isnull().head()
# Out:
#       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  int_rate
# 0  False       True      False        False            False  False     False  \
# 1  False       True      False        False            False  False     False
# 2  False       True      False        False            False  False     False
# 3  False       True      False        False            False  False     False
# 4  False       True      False        False            False  False     False
#
#    installment  grade  sub_grade  ...  hardship_last_payment_amount
# 0        False  False      False  ...                          True  \
# 1        False  False      False  ...                          True
# 2        False  False      False  ...                          True
# 3        False  False      False  ...                          True
# 4        False  False      False  ...                          True
#
#    disbursement_method  debt_settlement_flag  debt_settlement_flag_date
# 0                False                 False                       True  \
# 1                False                 False                       True
# 2                False                 False                       True
# 3                False                 False                       True
# 4                False                 False                       True
#
#    settlement_status  settlement_date  settlement_amount
# 0               True             True               True  \
# 1               True             True               True
# 2               True             True               True
# 3               True             True               True
# 4               True             True               True
#
#    settlement_percentage  settlement_term  charged_off
# 0                   True             True        False
# 1                   True             True        False
# 2                   True             True        False
# 3                   True             True        False
# 4                   True             True        False
#
# [5 rows x 151 columns]

# %% [markdown]
# The following code calculates the percentage null in each column.  As we can see there is a big jump in nulls from 13% to 50%.  So I am going to drop all columns that have nulls over 13%

# %%
df_percent_nulls = \
pd.DataFrame({
    "percent_nulls":np.round(df_binary.isnull().sum() / len(df_binary) * 100)
}).sort_values("percent_nulls").reset_index()
df_percent_nulls
# Out:
#                                           index  percent_nulls
# 0                                            id            0.0
# 1                                    revol_util            0.0
# 2                                     total_acc            0.0
# 3                           initial_list_status            0.0
# 4                                     out_prncp            0.0
# 5                                 out_prncp_inv            0.0
# 6                                   total_pymnt            0.0
# 7                               total_pymnt_inv            0.0
# 8                               total_rec_prncp            0.0
# 9                                 total_rec_int            0.0
# 10                           total_rec_late_fee            0.0
# 11                                   recoveries            0.0
# 12                      collection_recovery_fee            0.0
# 13                                 last_pymnt_d            0.0
# 14                                    revol_bal            0.0
# 15                              last_pymnt_amnt            0.0
# 16                         last_fico_range_high            0.0
# 17                          last_fico_range_low            0.0
# 18                   collections_12_mths_ex_med            0.0
# 19                                  policy_code            0.0
# 20                             application_type            0.0
# 21                               acc_now_delinq            0.0
# 22                     chargeoff_within_12_mths            0.0
# 23                                  delinq_amnt            0.0
# 24                         pub_rec_bankruptcies            0.0
# 25                                    tax_liens            0.0
# 26                                hardship_flag            0.0
# 27                          disbursement_method            0.0
# 28                         debt_settlement_flag            0.0
# 29                           last_credit_pull_d            0.0
# 30                                      pub_rec            0.0
# 31                                  charged_off            0.0
# 32                                         term            0.0
# 33                                  installment            0.0
# 34                                     int_rate            0.0
# 35                                        grade            0.0
# 36                              funded_amnt_inv            0.0
# 37                                    sub_grade            0.0
# 38                               home_ownership            0.0
# 39                                   annual_inc            0.0
# 40                          verification_status            0.0
# 41                                      issue_d            0.0
# 42                                   pymnt_plan            0.0
# 43                                          url            0.0
# 44                                  funded_amnt            0.0
# 45                                      purpose            0.0
# 46                                     open_acc            0.0
# 47                               inq_last_6mths            0.0
# 48                              fico_range_high            0.0
# 49                               fico_range_low            0.0
# 50                                    loan_amnt            0.0
# 51                             earliest_cr_line            0.0
# 52                                          dti            0.0
# 53                                   addr_state            0.0
# 54                                     zip_code            0.0
# 55                                  delinq_2yrs            0.0
# 56                                        title            1.0
# 57                                  num_bc_sats            4.0
# 58                         mths_since_recent_bc            4.0
# 59                                     mort_acc            4.0
# 60                               total_bc_limit            4.0
# 61                            total_bal_ex_mort            4.0
# 62                         acc_open_past_24mths            4.0
# 63                                     num_sats            4.0
# 64                                  avg_cur_bal            5.0
# 65                              num_actv_rev_tl            5.0
# 66                             percent_bc_gt_75            5.0
# 67                                      bc_util            5.0
# 68                         mo_sin_old_rev_tl_op            5.0
# 69                        mo_sin_rcnt_rev_tl_op            5.0
# 70                               mo_sin_rcnt_tl            5.0
# 71                               bc_open_to_buy            5.0
# 72                             total_rev_hi_lim            5.0
# 73                           num_tl_op_past_12m            5.0
# 74                                    num_il_tl            5.0
# 75                   total_il_high_credit_limit            5.0
# 76                              tot_hi_cred_lim            5.0
# 77                                 tot_coll_amt            5.0
# 78                                  tot_cur_bal            5.0
# 79                                    num_bc_tl            5.0
# 80                        num_accts_ever_120_pd            5.0
# 81                               num_actv_bc_tl            5.0
# 82                                 num_tl_30dpd            5.0
# 83                          num_rev_tl_bal_gt_0            5.0
# 84                                num_rev_accts            5.0
# 85                               pct_tl_nvr_dlq            5.0
# 86                                num_op_rev_tl            5.0
# 87                           num_tl_90g_dpd_24m            5.0
# 88                                    emp_title            6.0
# 89                                   emp_length            6.0
# 90                           mo_sin_old_il_acct            8.0
# 91                             num_tl_120dpd_2m            9.0
# 92                        mths_since_recent_inq           13.0
# 93                       mths_since_last_delinq           50.0
# 94                                  total_cu_tl           60.0
# 95                                       inq_fi           60.0
# 96                                     all_util           60.0
# 97                                   max_bal_bc           60.0
# 98                                  open_rv_24m           60.0
# 99                                 total_bal_il           60.0
# 100                                 open_il_24m           60.0
# 101                                 open_il_12m           60.0
# 102                                 open_act_il           60.0
# 103                                 open_acc_6m           60.0
# 104                                inq_last_12m           60.0
# 105                                 open_rv_12m           60.0
# 106                          mths_since_rcnt_il           61.0
# 107                                     il_util           65.0
# 108              mths_since_recent_revol_delinq           67.0
# 109                 mths_since_last_major_derog           74.0
# 110                    mths_since_recent_bc_dlq           76.0
# 111                      mths_since_last_record           83.0
# 112                                        desc           91.0
# 113                       settlement_percentage           98.0
# 114                           settlement_amount           98.0
# 115                             settlement_date           98.0
# 116                           settlement_status           98.0
# 117                   debt_settlement_flag_date           98.0
# 118                             settlement_term           98.0
# 119                            annual_inc_joint           98.0
# 120                                   dti_joint           98.0
# 121                   verification_status_joint           98.0
# 122                      sec_app_inq_last_6mths           99.0
# 123                     sec_app_fico_range_high           99.0
# 124                      sec_app_fico_range_low           99.0
# 125                             revol_bal_joint           99.0
# 126                    sec_app_earliest_cr_line           99.0
# 127                            sec_app_mort_acc           99.0
# 128            sec_app_chargeoff_within_12_mths           99.0
# 129                       sec_app_num_rev_accts           99.0
# 130                         sec_app_open_act_il           99.0
# 131                          sec_app_revol_util           99.0
# 132                            sec_app_open_acc           99.0
# 133          sec_app_collections_12_mths_ex_med           99.0
# 134              hardship_payoff_balance_amount          100.0
# 135                                   member_id          100.0
# 136                hardship_last_payment_amount          100.0
# 137  orig_projected_additional_accrued_interest          100.0
# 138                           hardship_end_date          100.0
# 139                                hardship_dpd          100.0
# 140                             hardship_length          100.0
# 141                     payment_plan_start_date          100.0
# 142                         hardship_start_date          100.0
# 143                             hardship_amount          100.0
# 144                               deferral_term          100.0
# 145                             hardship_status          100.0
# 146                               hardship_type          100.0
# 147                                next_pymnt_d          100.0
# 148         sec_app_mths_since_last_major_derog          100.0
# 149                        hardship_loan_status          100.0
# 150                             hardship_reason          100.0

# %% [markdown]
# Collecting list of columns that have greater that 13% nulls.

# %%
to_drop = list(df_percent_nulls.query("percent_nulls > 13")["index"].values)
to_drop
# Out:
# ['mths_since_last_delinq',
#  'total_cu_tl',
#  'inq_fi',
#  'all_util',
#  'max_bal_bc',
#  'open_rv_24m',
#  'total_bal_il',
#  'open_il_24m',
#  'open_il_12m',
#  'open_act_il',
#  'open_acc_6m',
#  'inq_last_12m',
#  'open_rv_12m',
#  'mths_since_rcnt_il',
#  'il_util',
#  'mths_since_recent_revol_delinq',
#  'mths_since_last_major_derog',
#  'mths_since_recent_bc_dlq',
#  'mths_since_last_record',
#  'desc',
#  'settlement_percentage',
#  'settlement_amount',
#  'settlement_date',
#  'settlement_status',
#  'debt_settlement_flag_date',
#  'settlement_term',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'sec_app_inq_last_6mths',
#  'sec_app_fico_range_high',
#  'sec_app_fico_range_low',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_mort_acc',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_num_rev_accts',
#  'sec_app_open_act_il',
#  'sec_app_revol_util',
#  'sec_app_open_acc',
#  'sec_app_collections_12_mths_ex_med',
#  'hardship_payoff_balance_amount',
#  'member_id',
#  'hardship_last_payment_amount',
#  'orig_projected_additional_accrued_interest',
#  'hardship_end_date',
#  'hardship_dpd',
#  'hardship_length',
#  'payment_plan_start_date',
#  'hardship_start_date',
#  'hardship_amount',
#  'deferral_term',
#  'hardship_status',
#  'hardship_type',
#  'next_pymnt_d',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_loan_status',
#  'hardship_reason']

# %%
len(to_drop)
# Out:
# 58

# %% [markdown]
# ### Dropping Mostly Null Columns

# %%
df_binary.drop(columns=to_drop, inplace=True)
df_binary.head(1).T
# Out:
#                                                                             0
# id                                                                   39460023
# loan_amnt                                                              5625.0
# funded_amnt                                                            5625.0
# funded_amnt_inv                                                        5625.0
# term                                                                36 months
# int_rate                                                                12.39
# installment                                                            187.89
# grade                                                                       C
# sub_grade                                                                  C1
# emp_title                                                             Teacher
# emp_length                                                            3 years
# home_ownership                                                           RENT
# annual_inc                                                            44000.0
# verification_status                                              Not Verified
# issue_d                                                              Jan-2015
# pymnt_plan                                                                  n
# url                         https://lendingclub.com/browse/loanDetail.acti...
# purpose                                                    debt_consolidation
# title                                                      Debt consolidation
# zip_code                                                                287xx
# addr_state                                                                 NC
# dti                                                                     23.65
# delinq_2yrs                                                               0.0
# earliest_cr_line                                                     Jul-1987
# fico_range_low                                                          730.0
# fico_range_high                                                         734.0
# inq_last_6mths                                                            1.0
# open_acc                                                                 13.0
# pub_rec                                                                   1.0
# revol_bal                                                             29458.0
# revol_util                                                               44.9
# total_acc                                                                34.0
# initial_list_status                                                         w
# out_prncp                                                                 0.0
# out_prncp_inv                                                             0.0
# total_pymnt                                                           6299.17
# total_pymnt_inv                                                       6299.17
# total_rec_prncp                                                        5625.0
# total_rec_int                                                          674.17
# total_rec_late_fee                                                        0.0
# recoveries                                                                0.0
# collection_recovery_fee                                                   0.0
# last_pymnt_d                                                         Feb-2016
# last_pymnt_amnt                                                       4048.36
# last_credit_pull_d                                                   Mar-2019
# last_fico_range_high                                                    604.0
# last_fico_range_low                                                     600.0
# collections_12_mths_ex_med                                                0.0
# policy_code                                                               1.0
# application_type                                                   Individual
# acc_now_delinq                                                            0.0
# tot_coll_amt                                                             80.0
# tot_cur_bal                                                          239578.0
# total_rev_hi_lim                                                      65600.0
# acc_open_past_24mths                                                      2.0
# avg_cur_bal                                                           18429.0
# bc_open_to_buy                                                        13497.0
# bc_util                                                                  64.9
# chargeoff_within_12_mths                                                  0.0
# delinq_amnt                                                               0.0
# mo_sin_old_il_acct                                                      176.0
# mo_sin_old_rev_tl_op                                                    330.0
# mo_sin_rcnt_rev_tl_op                                                     2.0
# mo_sin_rcnt_tl                                                            2.0
# mort_acc                                                                  4.0
# mths_since_recent_bc                                                     32.0
# mths_since_recent_inq                                                     2.0
# num_accts_ever_120_pd                                                     0.0
# num_actv_bc_tl                                                            5.0
# num_actv_rev_tl                                                           8.0
# num_bc_sats                                                               5.0
# num_bc_tl                                                                11.0
# num_il_tl                                                                 8.0
# num_op_rev_tl                                                            11.0
# num_rev_accts                                                            22.0
# num_rev_tl_bal_gt_0                                                       8.0
# num_sats                                                                 13.0
# num_tl_120dpd_2m                                                          0.0
# num_tl_30dpd                                                              0.0
# num_tl_90g_dpd_24m                                                        0.0
# num_tl_op_past_12m                                                        1.0
# pct_tl_nvr_dlq                                                           97.1
# percent_bc_gt_75                                                         80.0
# pub_rec_bankruptcies                                                      0.0
# tax_liens                                                                 1.0
# tot_hi_cred_lim                                                      293006.0
# total_bal_ex_mort                                                     48862.0
# total_bc_limit                                                        38400.0
# total_il_high_credit_limit                                            20093.0
# hardship_flag                                                               N
# disbursement_method                                                      Cash
# debt_settlement_flag                                                        N
# charged_off                                                             False

# %% [markdown]
# ### Writing to CSV

# %%
df_binary.to_csv("data_processed/02_mostly_nulls_removed.csv", index=False)
